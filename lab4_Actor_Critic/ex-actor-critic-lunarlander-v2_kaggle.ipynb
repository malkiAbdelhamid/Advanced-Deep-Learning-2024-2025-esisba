# %% [markdown]
# # Actor-Critic Algorithm
# In this notebook, you'll code The Actor-Critic Algorithm from scratch: .
#
# Actor-Critic algorithm is a *Policy-based method* that aims to reduce the variance of the Reinforce algorithm and train our agent faster and better by using a combination of Policy-Based and Value-Based methods
#
#
# To test its robustness, we're going to train it in Cartpole-v1 environment

# %% [markdown]
# ## Import the packages

# %%
# %pip install swig
# %pip install gymnasium[box2d]
# %pip install gymnasium
# Out:
# Collecting swig
#   Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Downloading swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 48.3 MB/s eta 0:00:0000:01
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium[box2d] in /opt/conda/lib/python3.10/site-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium[box2d]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium[box2d]) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium[box2d]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame>=2.1.3 (from gymnasium[box2d])
#   Downloading pygame-2.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: swig==4.* in /opt/conda/lib/python3.10/site-packages (from gymnasium[box2d]) (4.3.0)
# Downloading pygame-2.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 93.2 MB/s eta 0:00:00:00:010:01
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=495258 sha256=d60faead9787a31878f3a6c52477f7c1d581862aa0b9463a13b36742dec6bee3
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame
# Successfully installed box2d-py-2.3.5 pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium in /opt/conda/lib/python3.10/site-packages (0.29.0)
# Requirement already satisfied: numpy>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
from collections import deque
import matplotlib.pyplot as plt

# PyTorch
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical

# Gym
import gymnasium as gym

# %% [markdown]
# ## Check if we have a GPU
# - Let's check if we have a GPU `device:cuda0`

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %% [markdown]
# # Agent: Playing CartPole-v1 🤖
# ### The CartPole-v1 environment
#
# > A pole is attached by an un-actuated joint to a cart, which moves along a frictionless track. The pendulum is placed upright on the cart and the goal is to balance the pole by applying forces in the left and right direction on the cart.
#
# So, we start with CartPole-v1. The goal is to push the cart left or right **so that the pole stays in the equilibrium.**
#
# The episode ends if:
# - The pole Angle is greater than ±12°
# - Cart Position is greater than ±2.4
# - Episode length is greater than 500
#
# We get a reward 💰 of +1 every timestep the Pole stays in the equilibrium.

# %%
#env_id = "CartPole-v1"
env_id="LunarLander-v2"
# Create the env
env = gym.make(env_id)


# Get the state space and action space
s_size = env.observation_space.shape[0]
a_size = env.action_space.n

# %% [markdown]
# ## Let's build the A2C algo

# %%
#Using a neural network to learn our actor (policy) parameters

class Actor(nn.Module):
    def __init__(self, s_size, a_size, h_size):
        super(Actor, self).__init__()
        self.fc1 = nn.Linear(s_size, h_size)
        self.fc2 = nn.Linear(h_size, a_size)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return F.softmax(x, dim=1)

    def act(self, state):

        probs = self.forward(state)
        m = Categorical(probs)
        action = m.sample()
        return action.item(), m.log_prob(action)

# %%
#Using a neural network to learn state value
class Critic(nn.Module):

    #Takes in state
    def __init__(self, s_size, h_size):
        super(Critic, self).__init__()

        # two fully connected layers
        # add code here
        # add code here
        self.fc1 = nn.Linear(s_size, h_size)  # Input layer
        self.fc2 = nn.Linear(h_size, 1)       # Output layer

    def forward(self, x):

        #input layer
        x = self.fc1(x)  # Input layer

        #activiation relu
        x = F.relu(x)

        #get state value
        state_value = self.fc2(x)

        return state_value

# %% [markdown]
# # Building the parts of our algorithm #
# The main steps for building a A2C Algo are:
# 1. Generates a trajectory
# 2. Compute the discounted returns
# 3. Standardization of the returns
# 4. Train critic network
# 5. Train actor network

# %%
def generate_trajectory(actor, critic, max_t):
        saved_log_probs = []
        rewards = []
        state_values=[]

        state, _ = env.reset()
        for t in range(max_t):
            state=torch.from_numpy(state).float().unsqueeze(0).to(device)

            action, log_prob = actor.act(state) # add code here

            # get the state value from th critic network
            state_val= critic(state) # add code here

            next_state, reward, terminated, truncated, _ = env.step(action)
            done = terminated or truncated

            # add te obtained results to their relative lists ==> saved_log_probs, rewards, state_values

            # add code here
            # add code here
            # add code here
            saved_log_probs.append(log_prob)
            rewards.append(reward)
            state_values.append(state_val)

            state=next_state

            if done:

                break

        return  saved_log_probs, rewards, state_values

# %%
def computer_cumulative_reward(rewards, max_t,gamma):

        returns = deque(maxlen=max_t)
        n_steps = len(rewards)
        for t in range(n_steps)[::-1]:
          disc_return_t = (returns[0] if len(returns)>0 else 0)
          returns.appendleft( rewards[t]+gamma*disc_return_t)
        return returns

# %%
def returns_standardization(returns):
        eps = np.finfo(np.float32).eps.item()
        ## eps is the smallest representable float, which is
        # added to the standard deviation of the returns to avoid numerical instabilities
        returns = torch.tensor(returns).to(device)
        returns = (returns - returns.mean()) / (returns.std() + eps)

        return returns

# %%
def train_actor(actorOptimizer,saved_log_probs, returns,state_values):


        state_values= torch.stack(state_values).squeeze()

        #calculate Advantage for actor
        advantages = returns - state_values  # add code here

        #convect the advantages to a tensor
        advantages = advantages.detach()  # add code here

        actor_loss = []
        # compute the actor loss
        # add code here
          
        for log_prob, advantage in zip(saved_log_probs, advantages):
                actor_loss.append(-log_prob * advantage)  # Negative log likelihood scaled by advantage


        actor_loss = torch.cat(actor_loss).sum()
        # Backpropagate actor
        actorOptimizer.zero_grad()
        actor_loss.backward()
        actorOptimizer.step()

# %%
def train_critic(criticOptimizer, returns,state_values):
        state_values= torch.stack(state_values).squeeze()
        returns = torch.tensor(returns).float().to(device)
        critic_loss= F.mse_loss(state_values, returns)  # add code here

        # Backpropagate crtic
        criticOptimizer.zero_grad()
        critic_loss.backward()
        criticOptimizer.step()

# %% [markdown]
# ## Merge all functions into the Actor_Critic method ##
#
# You will now see how the overall **A2C Algo** is structured by putting together all the building blocks (functions implemented in the previous parts) together, in the right order.

# %%
def Actor_Critic(actor,critic, actorOptimizer,criticOptimizer, n_training_episodes, max_t, gamma, print_every):
    # Help us to calculate the score during the training
    scores_deque = deque(maxlen=100)
    scores = []

    for i_episode in range(1, n_training_episodes+1):

        # Generate an episode
        saved_log_probs, rewards, state_values = generate_trajectory(actor, critic, max_t)  # Generate Trajectory #add code here
        scores_deque.append(sum(rewards))
        scores.append(sum(rewards))

        # calculate the return
        returns= computer_cumulative_reward(rewards,max_t,gamma)

        ## standardization of the returns is employed to make training more stable
        returns=returns_standardization(returns)

        # Train the Critic network
        #add code here
        train_critic(criticOptimizer, returns, state_values) # Train critic
        # Train the Actor network
        #add code here
        train_actor(actorOptimizer, saved_log_probs, returns, state_values) # Train actor



        if i_episode % print_every == 0:
            print('Episode {}\tAverage Score: {:.2f}'.format(i_episode, np.mean(scores_deque)))

    return scores

# %% [markdown]
# ##  Train it
# - We're now ready to train our agent.
# - But first, we define a variable containing all the training hyperparameters.
# - You can change the training parameters (and should 😉)

# %%
cartpole_hyperparameters = {
    "h_size": 64,
    "n_training_episodes": 2500,
    "n_evaluation_episodes": 10,
    "max_t": 2500,
    "gamma": 1.0,
    "lr": 1e-2,
    "env_id": env_id,
    "state_space": s_size,
    "action_space": a_size,
}

# %%
# Create actor and place it to the device
cartpole_actor = Actor(s_size, a_size, cartpole_hyperparameters["h_size"]).to(device) #add code here

cartpole_actorOptimizer = optim.Adam(cartpole_actor.parameters(), lr=cartpole_hyperparameters["lr"]) #add code here

# %%
# Create critic and place it to the device
cartpole_critic =  Critic(s_size, cartpole_hyperparameters["h_size"]).to(device) #add code here
cartpole_criticOptimizer = optim.Adam(cartpole_critic.parameters(), lr=cartpole_hyperparameters["lr"]) #add code here

# %%
scores = Actor_Critic(cartpole_actor,
                   cartpole_critic,cartpole_actorOptimizer,cartpole_criticOptimizer,
                   cartpole_hyperparameters["n_training_episodes"],
                   cartpole_hyperparameters["max_t"],
                   cartpole_hyperparameters["gamma"],
                   100)
# Out:
# /tmp/ipykernel_30/3240655564.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   returns = torch.tensor(returns).float().to(device)
# Episode 100	Average Score: -146.01
# Episode 200	Average Score: -107.15
# Episode 300	Average Score: -87.45
# Episode 400	Average Score: -22.40
# Episode 500	Average Score: 13.86
# Episode 600	Average Score: 50.26
# Episode 700	Average Score: 123.86
# Episode 800	Average Score: 119.51
# Episode 900	Average Score: 123.81
# Episode 1000	Average Score: 184.04
# Episode 1100	Average Score: 221.95
# Episode 1200	Average Score: 226.35
# Episode 1300	Average Score: 196.50
# Episode 1400	Average Score: 220.42
# Episode 1500	Average Score: 222.57
# Episode 1600	Average Score: 237.76
# Episode 1700	Average Score: 170.75
# Episode 1800	Average Score: -124.14
# Episode 1900	Average Score: -279.20
# Episode 2000	Average Score: -221.20
# Episode 2100	Average Score: -281.18
# Episode 2200	Average Score: -284.27
# Episode 2300	Average Score: -286.41
# Episode 2400	Average Score: -334.56
# Episode 2500	Average Score: -208.57

# %%
scores= pd.Series(scores, name="scores_Actor")
scores.describe()
# Out:
# count    2500.000000
# mean      -10.835890
# std       227.979488
# min      -838.331631
# 25%      -192.809830
# 50%       -15.223290
# 75%       232.670186
# max       315.882408
# Name: scores_Actor, dtype: float64

# %%
fig, ax = plt.subplots(1, 1)
_ = scores.plot(ax=ax, label="scores_Actor")
_ = (scores.rolling(window=100)
           .mean()
           .rename("Rolling Average")
           .plot(ax=ax))
ax.legend()
_ = ax.set_xlabel("Episode Number")
_ = ax.set_ylabel("scores_Actor")
