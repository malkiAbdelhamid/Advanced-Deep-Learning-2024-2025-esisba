# %%
# %pip install -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt
# Out:
# Requirement already satisfied: numpy in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 1)) (2.1.2)
# Requirement already satisfied: gymnasium in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 2)) (1.0.0)
# Requirement already satisfied: pygame in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 3)) (2.6.1)
# Requirement already satisfied: jupyter in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.1.1)
# Requirement already satisfied: pandas in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 5)) (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (3.9.2)
# Requirement already satisfied: tqdm in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 7)) (4.66.5)
# Requirement already satisfied: imageio in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from -r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 8)) (2.35.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from gymnasium->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 2)) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from gymnasium->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 2)) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from gymnasium->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 2)) (0.0.4)
# Requirement already satisfied: notebook in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (7.2.2)
# Requirement already satisfied: jupyter-console in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (7.16.4)
# Requirement already satisfied: ipykernel in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (6.29.5)
# Requirement already satisfied: ipywidgets in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (8.1.5)
# Requirement already satisfied: jupyterlab in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from pandas->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 5)) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from pandas->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 5)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from pandas->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 5)) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from matplotlib->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 6)) (3.2.0)
# Requirement already satisfied: colorama in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from tqdm->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 7)) (0.4.6)
# Requirement already satisfied: imageio-ffmpeg in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from imageio[ffmpeg]->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 9)) (0.5.1)
# Requirement already satisfied: psutil in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from imageio[ffmpeg]->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 9)) (6.0.0)
# Requirement already satisfied: av in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from imageio[pyav]->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 10)) (13.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 5)) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from imageio-ffmpeg->imageio[ffmpeg]->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 9)) (75.1.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.8.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (8.28.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.1.7)
# Requirement already satisfied: nest-asyncio in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipywidgets->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipywidgets->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.0.13)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-console->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.0.48)
# Requirement already satisfied: pygments in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-console->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.18.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.27.2)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.1.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.14.2)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.0.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.0.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.5.1)
# Requirement already satisfied: tinycss2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.3.0)
# Requirement already satisfied: webencodings in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from bleach!=5.0.0->nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.5.1)
# Requirement already satisfied: anyio in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.6.0)
# Requirement already satisfied: certifi in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.0.6)
# Requirement already satisfied: idna in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.10)
# Requirement already satisfied: sniffio in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.14.0)
# Requirement already satisfied: decorator in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.19.1)
# Requirement already satisfied: stack-data in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.6.2)
# Requirement already satisfied: exceptiongroup in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.2.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (307)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.21.0)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.0.13)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (4.23.0)
# Requirement already satisfied: requests>=2.31 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.20.0)
# Requirement already satisfied: wcwidth in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.6)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.20.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.2.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (0.2.3)
# Requirement already satisfied: fqdn in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (3.0.0)
# Requirement already satisfied: uri-template in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (24.8.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\friha\.conda\envs\advanceddl\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->-r https://raw.githubusercontent.com/malkiAbdelhamid/Advanced-Deep-Learning-2024-2025-esisba/master/lab1_QLearning/requirements_lab1.txt (line 4)) (2.9.0.20241003)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
from tqdm import tqdm

import imageio

# %%
class SARSA_Agent:

    def __init__(self, env, alpha, gamma, max_epsilon, min_epsilon, decay_rate):

        self.env = env

        # table with q-values: n_states * n_actions
        self.q_table=np.zeros((env.observation_space.n, env.action_space.n))

        # hyper-parameters
        self.alpha = alpha                      # learning rate
        self.gamma = gamma                      # discount factor
        self.max_epsilon = max_epsilon          # Exploration probability at start
        self.min_epsilon = min_epsilon          # Minimum exploration probability
        self.decay_rate =  decay_rate           # Exponential decay rate for exploration prob



    # get action using epsilon greedy polic
    def get_action(self, state, epsilon):
        # Randomly generate a number between 0 and 1
        random_num =random.uniform(0,1)

        # if random_num > greater than epsilon --> exploitation
        if random_num > epsilon:
           # Take the action with the highest value given a state
           # np.argmax can be useful here
           action = np.argmax(self.q_table[state])

        # else --> exploration
        else:
           action = self.env.action_space.sample()

        return action

    def update_parameters(self, state, action, reward, next_state,epsilon):
        """"""
        # SARSA-learning formula
        # Update Q(s,a):= Q(s,a) + lr [R(s,a)  + gamma * Q(s',a') - Q(s,a)]
        #--- add code here (4 lines)----------
        next_action = self.get_action(next_state, epsilon)  # Get next action
        new_value = self.q_table[state, action] + self.alpha * (reward + self.gamma * self.q_table[next_state, next_action] - self.q_table[state, action])
      
         

        # update the q_table
        self.q_table[state, action] = new_value

# %%
def train(n_training_episodes, max_steps, env, agent):

  episode_rewards = []
  episode_penalties = []
  episode_steps = []
  for episode in tqdm(range(n_training_episodes)):

    total_rewards_ep = 0
    total_penalties_ep=0
    total_steps_ep=0

    # Reduce epsilon (because we need less and less exploration)
    epsilon = agent.min_epsilon + (agent.max_epsilon - agent.min_epsilon)*np.exp(-agent.decay_rate*episode)

    # Reset the environment
    state, info = env.reset()
    step = 0
    terminated = False
    truncated = False
    done=False

    # repeat
    while not done:
      # Choose the action At using epsilon greedy policy
      action = agent.get_action(state, epsilon)

      # Take action At and observe Rt+1 and St+1
      # Take the action (a) and observe the outcome state(s') and reward (r)
      next_state, reward, terminated, truncated, info = env.step(action)

      total_rewards_ep += reward
      total_steps_ep +=1
      if reward == -10:
            total_penalties_ep += 1

      # Update Q(s,a):= Q(s,a) + lr [R(s,a)  + gamma * Q(s',a') - Q(s,a)]
      agent.update_parameters(state, action, reward, next_state, epsilon)
      # If terminated or truncated finish the episode
      done=terminated or truncated

      if done:
        break

      # Our next state is the new state
      state = next_state

      episode_rewards.append(total_rewards_ep)
      episode_steps.append(total_steps_ep)
      episode_penalties.append(total_penalties_ep)

  return  episode_rewards,episode_steps, episode_penalties

# %%
# Training parameters
n_training_episodes = 1000  # Total training episodes
alpha= 0.7          # Learning rate

# Evaluation parameters
n_eval_episodes = 100        # Total number of test episodes

# Environment parameters
max_steps = 99               # Max steps per episode
gamma = 0.95                 # Discounting rate
eval_seed = []               # The evaluation seed of the environment

# Exploration parameters
max_epsilon = 1.0             # Exploration probability at start
min_epsilon = 0.05            # Minimum exploration probability
decay_rate = 0.0005            # Exponential decay rate for exploration prob

# %%
#env=gym.make("FrozenLake-v1", map_name="4x4", is_slippery=False, render_mode="rgb_array")
env=gym.make("Taxi-v3", render_mode="rgb_array")

agent=SARSA_Agent(env, alpha, gamma, max_epsilon, min_epsilon, decay_rate)

episode_rewards,episode_steps, episode_penalties=train(n_training_episodes, max_steps, env,agent)
# Out:
# 100%|██████████| 1000/1000 [00:10<00:00, 94.04it/s]

# %%
fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Cumulative Rewards per ride")
pd.Series(episode_rewards).plot(kind='line')
plt.show()

fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Timesteps to complete ride")
pd.Series(episode_steps).plot(kind='line')
plt.show()

fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Penalties per ride")
pd.Series(episode_penalties).plot(kind='line')
plt.show()

# %% [markdown]
# ### Evaluate the QAgent after training

# %%
def evaluate_agent(env,agent,  n_eval_episodes):
  """
  Evaluate the agent for ``n_eval_episodes`` episodes and returns average reward and std of reward.
  :param agent: the gent within its  evaluation environment and Qtable
  :param max_steps: Maximum number of steps per episode
  :param n_eval_episodes: Number of episode to evaluate the agent
   """
  episode_rewards = []
  episode_penalties = []
  episode_steps = []
  for episode in tqdm(range(n_eval_episodes)):

    state, info= env.reset()
    step = 0
    truncated = False
    terminated = False
    total_rewards_ep = 0
    total_penalties_ep=0
    total_steps_ep=0
    done= False

    while not done:
      # Take the action (index) that have the maximum expected future reward given that state
      # we use epsilon=0 for exploitation

      action = agent.get_action(state,0)
      next_state, reward, terminated, truncated, info = env.step(action)

      total_rewards_ep += reward
      total_steps_ep+=1

      if reward == -10:
            total_penalties_ep += 1

      done=terminated or truncated

      if done:
        break

      state = next_state

    episode_rewards.append(total_rewards_ep)
    episode_steps.append(total_steps_ep)
    episode_penalties.append(total_penalties_ep)

  mean_reward = np.mean(episode_rewards)
  std_reward = np.std(episode_rewards)

  return mean_reward, std_reward, episode_rewards,episode_steps, episode_penalties

# %%
mean_reward, std_reward,episode_rewards,episode_steps, episode_penalties=evaluate_agent(env,agent, 1000)
print(f"Mean_reward={mean_reward:.2f} +/- {std_reward:.2f}")
# Out:
#   1%|          | 10/1000 [00:00<00:10, 94.89it/s]
# 100%|██████████| 1000/1000 [00:05<00:00, 180.91it/s]
# Mean_reward=-198.31 +/- 18.83

# %%
fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Cumulative Rewards per ride")
pd.Series(episode_rewards).plot(kind='line')
plt.show()

fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Timesteps to complete ride")
pd.Series(episode_steps).plot(kind='line')
plt.show()

fig, ax = plt.subplots(figsize = (12, 4))
ax.set_title("Penalties per ride")
pd.Series(episode_penalties).plot(kind='line')
plt.show()

# %% [markdown]
# ### Record a simulation as a video

# %%
def record_video(env, agent, out_directory, fps=1):
  """
  Generate a replay video of the agent
  :param env
  :param agent:  agent within its Qtable
  :param out_directory
  :param fps: how many frame per seconds (with taxi-v3 and frozenlake-v1 we use 1)
  """
  images = []
  terminated = False
  truncated = False
  state, info = env.reset(seed=random.randint(0,500))
  img = env.render()
  images.append(img)
  while not terminated or truncated:
    # Take the action (index) that have the maximum expected future reward given that state
    action = np.argmax(agent.q_table[state][:])
    state, reward, terminated, truncated, info = env.step(action) # We directly put next_state = state for recording logic
    img = env.render()
    images.append(img)
  imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)

# %%
from base64 import b64encode
from IPython.display import HTML

# generate the video
video_path = "./replay.mp4"
record_video(env, agent, video_path, 1)

# Show video
mp4 = open(video_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""<video width=400 controls>      <source src="%s" type="video/mp4"></video>""" % data_url)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 6
#       4 # generate the video
#       5 video_path = "./replay.mp4"
# ----> 6 record_video(env, agent, video_path, 1)
#       8 # Show video
#       9 mp4 = open(video_path,'rb').read()
#
# Cell In[12], line 19, in record_video(env, agent, out_directory, fps)
#      17   action = np.argmax(agent.q_table[state][:])
#      18   state, reward, terminated, truncated, info = env.step(action) # We directly put next_state = state for recording logic
# ---> 19   img = env.render()
#      20   images.append(img)
#      21 imageio.mimsave(out_directory, [np.array(img) for i, img in enumerate(images)], fps=fps)
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\wrappers\common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\core.py:332, in Wrapper.render(self)
#     330 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     331     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 332     return self.env.render()
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\wrappers\common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\envs\toy_text\taxi.py:327, in TaxiEnv.render(self)
#     325     return self._render_text()
#     326 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 327     return self._render_gui(self.render_mode)
#
# File c:\Users\friha\.conda\envs\AdvancedDL\lib\site-packages\gymnasium\envs\toy_text\taxi.py:456, in TaxiEnv._render_gui(self, mode)
#     453     self.clock.tick(self.metadata["render_fps"])
#     454 elif mode == "rgb_array":
#     455     return np.transpose(
# --> 456         np.array(pygame.surfarray.pixels3d(self.window)), axes=(1, 0, 2)
#     457     )
#
# MemoryError: Unable to allocate 564. KiB for an array with shape (550, 350, 3) and data type uint8
